# %% [markdown]
# <a href="https://colab.research.google.com/github/CleoHabets/MAI3004_RevealingResistance/blob/main/PersonalCrossVal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Loading
# Run all these cell first

# %%
# Basic libraries
import pandas as pd

import numpy as np

import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

import seaborn as sns

# Machine learning
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.model_selection import (
    train_test_split,
    StratifiedKFold,
    GridSearchCV,
    cross_val_score
)
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, FunctionTransformer
from sklearn.metrics import (
    accuracy_score,
    classification_report,
    roc_auc_score,
    roc_curve,
    confusion_matrix,
    ConfusionMatrixDisplay
)
from sklearn.dummy import DummyClassifier # For baseline/ comparison model
from sklearn.linear_model import LogisticRegression
from sklearn.neural_network import MLPClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
import random
from tensorflow import keras

from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    roc_curve,
    confusion_matrix
)

# %%
import pandas as pd
import numpy as np
from scipy.sparse import load_npz

# X: Label (DataFrames)
train_X_label = pd.read_csv("train_X_label.csv", index_col=0)
test_X_label  = pd.read_csv("test_X_label.csv", index_col=0)

# X: OneHot (Sparse matrices)
train_X_OneHot = load_npz("train_X_OneHot.npz")
test_X_OneHot  = load_npz("test_X_OneHot.npz")

# X: FCGR (NumPy arrays)
train_X_fcgr = np.load("train_X_fcgr.npy")
test_X_fcgr  = np.load("test_X_fcgr.npy")

# y: load as Series (each CSV is a 1-col file)
train_y_CIP = pd.read_csv("train_y_CIP.csv", index_col=0).iloc[:, 0]
test_y_CIP  = pd.read_csv("test_y_CIP.csv", index_col=0).iloc[:, 0]

train_y_CTX = pd.read_csv("train_y_CTX.csv", index_col=0).iloc[:, 0]
test_y_CTX  = pd.read_csv("test_y_CTX.csv", index_col=0).iloc[:, 0]

train_y_CTZ = pd.read_csv("train_y_CTZ.csv", index_col=0).iloc[:, 0]
test_y_CTZ  = pd.read_csv("test_y_CTZ.csv", index_col=0).iloc[:, 0]

train_y_GEN = pd.read_csv("train_y_GEN.csv", index_col=0).iloc[:, 0]
test_y_GEN  = pd.read_csv("test_y_GEN.csv", index_col=0).iloc[:, 0]

# %%
train_X_fcgr_flat = train_X_fcgr.reshape(train_X_fcgr.shape[0], -1)
test_X_fcgr_flat  = test_X_fcgr.reshape(test_X_fcgr.shape[0], -1)

# %%
X_label = pd.concat([train_X_label, test_X_label])
from scipy.sparse import vstack
X_OneHot = vstack([train_X_OneHot, test_X_OneHot])
X_fcgr = np.vstack([train_X_fcgr_flat, test_X_fcgr_flat])

y_CIP = pd.concat([train_y_CIP, test_y_CIP])
y_CTX = pd.concat([train_y_CTX, test_y_CTX])
y_CTZ = pd.concat([train_y_CTZ, test_y_CTZ])
y_GEN = pd.concat([train_y_GEN, test_y_GEN])

# %%
def runmodel(train_X, train_y, test_X, test_y, model_chosen, X_name, Y_name, balance_method):

    if balance_method == "class_weight":
        cw = "balanced"
    else:
        cw = None

    if balance_method == "over_sample":
        from imblearn.over_sampling import RandomOverSampler
        ros = RandomOverSampler(random_state=42)
        train_X, train_y = ros.fit_resample(train_X, train_y)
    else:
        pass

    if model_chosen == "logistic_regression":
        model = LogisticRegression(max_iter=2000, class_weight=cw)

    elif model_chosen == "random_forrest":
        model = RandomForestClassifier(
            n_estimators=200,
            max_depth=None,
            min_samples_leaf=2,
            max_features="sqrt",
            n_jobs=-1,
            random_state=1,
            class_weight=cw
        )

    elif model_chosen == "SVM":
        model = SVC(kernel="linear", probability=True, random_state=1, class_weight=cw)

    else:
        raise ValueError("Unknown model")

    model.fit(train_X, train_y)

    y_pred = model.predict(test_X)

    if hasattr(model, "predict_proba"):
        y_score = model.predict_proba(test_X)[:, 1]
    else:
        y_score = model.decision_function(test_X)

    acc  = accuracy_score(test_y, y_pred)
    prec = precision_score(test_y, y_pred, zero_division=0)
    rec  = recall_score(test_y, y_pred, zero_division=0)
    f1   = f1_score(test_y, y_pred, zero_division=0)
    auc  = roc_auc_score(test_y, y_score)

    fpr, tpr, thresholds = roc_curve(test_y, y_score)
    cm = confusion_matrix(test_y, y_pred, normalize="true")

    return {
        "model": model_chosen,
        "X_encoding": X_name,
        "antibiotic": Y_name,
        "accuracy": float(acc),
        "precision": float(prec),
        "recall": float(rec),
        "f1": float(f1),
        "roc_auc": float(auc),
        "confusion_matrix": cm,
        "fpr": fpr,
        "tpr": tpr,
        "thresholds": thresholds,
    }

# %%
def cross_validate_model(X, y, model_chosen, X_name, Y_name, balance_method):

  if balance_method in ["over_sample", "class_weight", "none"]:
    pass
  else:
    raise ValueError("Unknown balance method")

  results = []

  for seed in range(0, 5):
    train_X, test_X, train_y, test_y = train_test_split(X, y, test_size = 0.2, stratify = y, random_state = seed)

    res = runmodel(train_X, train_y, test_X, test_y, model_chosen, X_name, Y_name, balance_method)
    results.append(res)

  metrics = ["accuracy", "precision", "recall", "f1", "roc_auc"]

  mean_metrics = {m: np.mean([r[m] for r in results]) for m in metrics}
  std_metrics  = {m: np.std([r[m] for r in results]) for m in metrics}
  cms = [r["confusion_matrix"] for r in results]
  cm_mean = np.mean(cms, axis=0)

  mean_fpr = np.linspace(0, 1, 200)
  tprs = []

  for r in results:
    fpr = r["fpr"]
    tpr = r["tpr"]

    tpr_interp = np.interp(mean_fpr, fpr, tpr)
    tpr_interp[0] = 0.0
    tprs.append(tpr_interp)

  mean_tpr = np.mean(tprs, axis=0)
  mean_tpr[-1] = 1.0

  final_result = {
      "model": results[0]["model"],
      "X_encoding": results[0]["X_encoding"],
      "antibiotic": results[0]["antibiotic"],
      "balance_method" : balance_method,

      "accuracy_mean": float(mean_metrics["accuracy"]),
      "accuracy_std": float(std_metrics["accuracy"]),
      "precision_mean": float(mean_metrics["precision"]),
      "precision_std": float(std_metrics["precision"]),
      "recall_mean": float(mean_metrics["recall"]),
      "recall_std": float(std_metrics["recall"]),
      "f1_mean": float(mean_metrics["f1"]),
      "f1_std": float(std_metrics["f1"]),
      "roc_auc_mean": float(mean_metrics["roc_auc"]),
      "roc_auc_std": float(std_metrics["roc_auc"]),

      "confusion_matrix": cm_mean,
      "fpr": mean_fpr,
      "tpr": mean_tpr,
  }

  return(final_result)

# %% [markdown]
# # Workspace

# %%
# Importing pickle to open files
import pickle

with open(, "rb") as f:
    all_results_balanced = pickle.load(f)"/content/genomic_ml_results_partial_balanced (8).pkl"

print("Loaded", len(all_results_balanced), "completed runs")
# Out:
# Loaded 30 completed runs

# %%
# Creating a list where we can append all cv results
cv_results = []

# %% [markdown]
# ## **CV Logistic Regression**

# %% [markdown]
# ### Label encoded LR

# %%
res = cross_validate_model(X_label, y_CIP, "logistic_regression", label, CIP, "none")
cv_results.append(res)

# %%
res = cross_validate_model(X_label, y_CTX, "logistic_regression", label, CTX, "none")
cv_results.append(res)

# %%
res = cross_validate_model(X_label, y_CTZ, "logistic_regression", label, CTZ, "over_sample")
cv_results.append(res)

# %%
res = cross_validate_model(X_label, y_GEN, "logistic_regression", label, GEN, "over_sample")
cv_results.append(res)

# %% [markdown]
# ### OneHot encoded LR

# %%
res = cross_validate_model(X_OneHot, y_CIP, "logistic_regression", OneHot, CIP, "none")
cv_results.append(res)

# %%
res = cross_validate_model(X_OneHot, y_CTX, "logistic_regression", OneHot, CTX, "none")
cv_results.append(res)

# %%
res = cross_validate_model(X_OneHot, y_CTZ, "logistic_regression", OneHot, CTZ, "over_sample")
cv_results.append(res)

# %%
res = cross_validate_model(X_OneHot, y_GEN, "logistic_regression", OneHot, GEN, "over_sample")
cv_results.append(res)

# %% [markdown]
# ### Fcgr encoded LR

# %%
res = cross_validate_model(X_fcgr, y_CIP, "logistic_regression", fcgr, CIP, "none")
cv_results.append(res)

# %%
res = cross_validate_model(X_fcgr, y_CTX, "logistic_regression", fcgr, CTX, "none")
cv_results.append(res)

# %%
res = cross_validate_model(X_fcgr, y_CTZ, "logistic_regression", fcgr, CTZ, "over_sample")
cv_results.append(res)

# %%
res = cross_validate_model(X_fcgr, y_GEN, "logistic_regression", fcgr, GEN, "over_sample")
cv_results.append(res)

# %% [markdown]
# ## **CV Random Forest**

# %% [markdown]
# ### Label encoded RF

# %%
res = cross_validate_model(X_label, y_CIP, "random_forrest", label, CIP, "none")
cv_results.append(res)

# %%
res = cross_validate_model(X_label, y_CTX, "random_forrest", label, CTX, "none")
cv_results.append(res)

# %%
res = cross_validate_model(X_label, y_CTZ, "random_forrest", label, CTZ, "over_sample")
cv_results.append(res)

# %%
res = cross_validate_model(X_label, y_GEN, "random_forrest", label, GEN, "over_sample")
cv_results.append(res)

# %% [markdown]
# ### OneHot encoded RF

# %%
res = cross_validate_model(X_OneHot, y_CIP, "random_forrest", OneHot, CIP, "none")
cv_results.append(res)

# %%
res = cross_validate_model(X_OneHot, y_CTX, "random_forrest", OneHot, CTX, "none")
cv_results.append(res)

# %%
res = cross_validate_model(X_OneHot, y_CTZ, "random_forrest", OneHot, CTZ, "over_sample")
cv_results.append(res)

# %%
res = cross_validate_model(X_OneHot, y_GEN, "random_forrest", OneHot, GEN, "over_sample")
cv_results.append(res)

# %% [markdown]
# ### Fcgr encoded RF

# %%
res = cross_validate_model(X_fcgr, y_CIP, "random_forrest", fcgr, CIP, "none")
cv_results.append(res)

# %%
res = cross_validate_model(X_fcgr, y_CTX, "random_forrest", fcgr, CTX, "none")
cv_results.append(res)

# %%
res = cross_validate_model(X_fcgr, y_CTZ, "random_forrest", fcgr, CTZ, "over_sample")
cv_results.append(res)

# %%
res = cross_validate_model(X_fcgr, y_GEN, "random_forrest", fcgr, GEN, "over_sample")
cv_results.append(res)

# %% [markdown]
# ## **CV Support Vector Machine**

# %% [markdown]
# ### Label encoded SVM

# %%
res = cross_validate_model(X_label, y_CIP, "SVM", label, CIP, "none")
cv_results.append(res)

# %%
res = cross_validate_model(X_label, y_CTX, "SVM", label, CTX, "none")
cv_results.append(res)

# %%
res = cross_validate_model(X_label, y_CTZ, "SVM", label, CTZ, "over_sample")
cv_results.append(res)

# %%
res = cross_validate_model(X_label, y_GEN, "SVM", label, GEN, "over_sample")
cv_results.append(res)

# %% [markdown]
# ### OneHot encoded SVM

# %%
res = cross_validate_model(X_OneHot, y_CIP, "SVM", OneHot, CIP, "none")
cv_results.append(res)

# %%
res = cross_validate_model(X_OneHot, y_CTX, "SVM", OneHot, CTX, "none")
cv_results.append(res)

# %%
res = cross_validate_model(X_OneHot, y_CTZ, "SVM", OneHot, CTZ, "over_sample")
cv_results.append(res)

# %%
res = cross_validate_model(X_OneHot, y_GEN, "SVM", OneHot, GEN, "over_sample")
cv_results.append(res)

# %% [markdown]
# ### Fcgr encoded SVM

# %%
res = cross_validate_model(X_fcgr, y_CIP, "SVM", fcgr, CIP, "none")
cv_results.append(res)

# %%
res = cross_validate_model(X_fcgr, y_CTX, "SVM", fcgr, CTX, "none")
cv_results.append(res)

# %%
res = cross_validate_model(X_fcgr, y_CTZ, "SVM", fcgr, CTZ, "over_sample")
cv_results.append(res)

# %%
res = cross_validate_model(X_fcgr, y_GEN, "SVM", fcgr, GEN, "over_sample")
cv_results.append(res)

# %% [markdown]
# ## Saving the results

# %%
# Run these two blocks after every 1 or 2 cross validated models have ran, so they get stored in a file.
import pickle
with open("all_cv_results", "wb") as f:
    pickle.dump(cv_results, f)

# %%
from google.colab import files
files.download("all_cv_results.pkl")

# %% [markdown]
# # Results checking

# %%
df_cv_results = pd.DataFrame(cv_results)

# %%
df_table_cv = df_cv_results[[
    "model",
    "X_encoding",
    "antibiotic",
    "accuracy",
    "precision",
    "recall",
    "f1",
    "roc_auc"
]]

# %%
df_results = pd.DataFrame(all_results)

# %%
df_table = df_results[[
    "model",
    "X_encoding",
    "antibiotic",
    "accuracy",
    "precision",
    "recall",
    "f1",
    "roc_auc"
]]
